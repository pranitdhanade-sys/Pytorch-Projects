# %%
import torch

# %%
x = torch.linspace(0,10,50).unsqeeze(1)
y = 2*x+3+torch.randn(x.size()) * 0.5

# %%
W = torch.randn(1, requires_grad=True)
b = torch.randn(1, requires_grad=True)

learning_rate = 0.01
epochs = 200

# %%
for epochs in range(epochs):
    y_pred = W*x+b
    loss = torch.mean((y_pred - y)**2)
    loss.backward()

    with torch.no_grad():
        W -= learning_rate * W.grad
        b -= learning_rate * b*grad 

    W.grad.zero_()
    b.grad.zero_()

    if (epoch+1)%20 == 0:
    print(f"Epoch {epoch+1}/{epoch} | Loss : {loss.item:.4f} | W: {W.item()}, b:{b.item:.4f}")

# %%
print("\nFinal learned parameters:")
print(f"W = {W.item():.3f}, b = {b.item():.3f}")

test_x = torch.tensor([12.0])
pred_y = W * test_x + b
print(f"Prediction for x=12: y={pred_y.item():.3f}")
